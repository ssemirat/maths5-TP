# %% [markdown]
# Double cliquer et entrer nom, prénom et groupe ici

# %% [markdown]
# # TP 2 : Régression par minimisation avec 2 variables
#
# ## Problème 1
# On considère les points $(1,3)$, $(3,3)$ et $(5,4)$
#
# On cherche l'ordonnée à l'origine $b$ et le coefficient directeur $w$ de la droite d'équation $$y=wx+b$$ minimisant la somme des carrés des distances verticales entre les points et la droite (comme représenté ci-dessous) :
# ![image.png](attachment:image.png)
#
# **Exercice 1 (sur papier).**
# 1. Modéliser le programme d'optimisation à résoudre.
# 2. Montrer que le critère, noté $f(b,w)$, est une fonction convexe.
# 3. Résoudre $[\text{grad f}](b,w)=\left(\begin{array}{cc}0&0\end{array}\right)$ et conclure.

# %% [markdown]
# *Répondre ici, en complétant :*
# - Variables :
# - Domaine :
# - Critère :
#
# Solution : b*=...., w*=....

# %% [markdown]
# ## Exploration graphique
# *Ne pas oublier d'exécuter les cellules suivantes, via `CTRL+Entrée`*

# %%
# Chargement des librairies Python

# Mathématiques 
import numpy as np

# Graphique
from matplotlib import pyplot as plt

# %% [markdown]
# ### Définition du nuage de points
#
# La liste des points $(1,3)$, $(3,3)$ et $(5,4)$ se définit par la liste des abscisses et la liste des ordonnées.

# %%
X=[1,3,5]
Y=[3,3,4]

# %% [markdown]
# ### Visualisation des points

# %%
plt.axis([0,6,0,5]) # xmin,xmax,ymin,ymax
plt.plot(X,Y,'o') # représentation graphique des points

# %% [markdown]
# ### Visualisation d'une droite de régression (pas forcément optimale)

# %%
w=1
b=1
plt.axis([0,6,0,8])
plt.plot(X,Y,'o')
plt.plot([0,6],[b+w*0,b+w*6])
for i in range(len(X)):
    plt.plot([X[i],X[i]],[Y[i],b+w*X[i]],'*--')
    
dTotale=0
for i in range(len(X)):
    di=(Y[i]-(b+w*X[i]))**2
    plt.text(X[i],(Y[i]+b+w*X[i])/2,' $d_'+str(i)+'^2=$'+str(di))
    dTotale=dTotale+di
plt.text(0,6,' $\sum d_i^2=$'+str(dTotale))
# Out:
# Text(0, 6, ' $\\sum d_i^2=$6')

# %% [markdown]
# ***Exercice 2***
#
# Vérifier à l'aide de la figure ci-dessus que les valeurs $b^*$ et $w^*$ trouvées à l'exercice 1 minimise bien la somme des carrés des distances verticales à la droite.

# %% [markdown]
# ## Représentation graphique de la fonction à minimiser
#
# ### Définition de la fonction

# %%
def f(b,w):
    return np.sum([(b+w*X[i]-Y[i])**2 for i in range(len(X))])

# %% [markdown]
# ### Création d'un tableau de valeurs pour $f$

# %% [markdown]
# ***Exercice 3***
#
# Les valeurs de $f$ sont à calculer pour un ensemble de $b$ et un ensemble de $w$.
#
# Pour créer un tableau de valeurs de $f$, il faut donc faire varier $b$ et $w$ simultanément.
#
# On construit une liste de valeurs de $w$, puis, pour chaque valeur de $w$, une liste de valeurs de $b$, selon le principe suivant :
# - `Liste1=[1,2,3,4]`
# - `Liste2=[1,2,3,4]`
# - `Valeurs=[[calcul(x,y) for x in Liste1] for y in Liste2]]`
#
# En supposant par exemple que `calcul(x,y)=x*y', quel sera le contenu de la liste `Valeurs` ci-dessus à l'issue de l'éxécution du code ?

# %% [markdown]
# *Réponde ici*

# %%
# Tableau de valeur de f

wlist=np.linspace(-5,5,50) # crée une liste de 50 nombres régulièrement espacés entre -5 et 5
blist=np.linspace(-5,5,50) # crée une liste de 50 nombres régulièrement espacés entre -5 et 5
flist=[[f(b,w) for b in blist] for w in wlist] # Tableau de valeur à 2 dimensions

# %% [markdown]
# **Exercice 4**
#
# Quels sont les 5 premières valeurs de $b$ et $w$ pour lesquelles est calculé $f(b,w)$ dans la liste `flist` du code ci-dessus ?

# %% [markdown]
# *Répondre ici*

# %% [markdown]
# ### Représentation graphique de la fonction

# %%
plt.axis([-5,5,-5,5]) #xmin,xmax,ymin,ymax
plt.contour(blist,wlist,flist,100) # crée 100 courbes de niveau de la fonction f
plt.colorbar() # affiche une légende avec les niveaux

# %% [markdown]
# **Exercice 5.**
#
# Changer le tableau de valeur ainsi que les valeurs xmin,xmax,ymin,ymax du graphique précédent afin de visualiser au mieux sur le graphique la solution $(b^*,w^*)$ optimale calculée dans l'exercice 1.

# %% [markdown]
# ## Représentation du nuage et de la droite de régression optimale

# %% [markdown]
# **Exercice 6**
#
# Modifier les valeurs de $b$ et $w$ ci-dessous pour représenter le nuage des 3 points ainsi que la droite de régression.

# %%
w=1
b=1
plt.axis([0,6,0,8])
plt.plot(X,Y,'o')
plt.plot([0,6],[b+w*0,b+w*6])

# %% [markdown]
# ## Problème 2
#
# On se donne un paquet de 20 points (générés aléatoirement), on cherche à déterminer la droite $y=b+wx$ minimisant la somme des carrés des distances verticales entre les points et la droite
#
# N'oubliez pas d'éxécuter le code générant le nouveau nuage de points !

# %% [markdown]
# ### Génération aléatoire des points

# %%
# Génère uniformément 20 nombres entre 0 et 10
X=np.random.uniform(0, 10, 20)
# Génère 20 nombres y autour de la droite y=2x+3
# la fonction np.random.random_sample() renvoie un nombre aléatoire entre 0 et 1
Y=[2*X[i]+3 for i in range(len(X))]
Y=Y+(np.random.uniform(0,6,20)-3) # ajoute un nombre aléatoire entre -1 et 1 à tous les Y[i]
print('X=',X)
print('Y=',Y)
# Out:
# X= [9.42910133 6.48557327 5.08265287 1.02907803 0.33799011 4.64663759
#  5.43124916 5.79296115 6.61681737 4.03711656 4.69289961 0.73362036
#  8.19829752 4.27964143 8.42568605 0.67033439 6.43967519 7.56464173
#  6.56215031 9.60771863]
# Y= [22.38089253 18.2488066  10.2272905   5.14844059  5.00162184 10.30188186
#  15.70224189 11.73274358 15.39314384 10.74161916 14.98316379  2.13984189
#  17.99087549  9.12625271 22.31307995  4.54364032 15.1801353  16.67827428
#  14.12397761 23.0235022 ]

# %% [markdown]
# ### Réprésentation du nuage des points

# %%
plt.axis([0,10,0,30])
plt.plot(X,Y,'o')

# %% [markdown]
# **Exercice 5.**
#
# En vous inspirant des calculs précédent, compléter par copié-collé les cellules ci-dessous afin de résoudre graphiquement le problème :
# - Programmer la fonction $f$ à minimiser
# - Calculer un tableau de valeurs de $f$
# - Représenter les courbes de niveau de $f$
# - Déterminer une valeur approximative de son minimum en lisant le graphique
# - Tracer le nuage de point ainsi que la droite de régression trouvée
